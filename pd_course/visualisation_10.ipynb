# %% [markdown]
# VISUALISATIO X

# %%
import pandas as pd 
from pandas_datareader import data 
import matplotlib.pyplot as plt

# %%
df = data.DataReader(
    name="BB", data_source="stooq", start="2010-1-1", end="2020-12-31"
)

# %%
df
# Out:
#              Open   High     Low  Close      Volume
# Date
# 2020-12-31   6.68   6.80   6.630   6.63   7530565.0
# 2020-12-30   6.79   6.81   6.600   6.67   9434913.0
# 2020-12-29   6.98   7.00   6.675   6.77  11284185.0
# 2020-12-28   7.10   7.13   6.850   6.88   9820108.0
# 2020-12-24   7.12   7.24   7.050   7.06   6088342.0
# ...           ...    ...     ...    ...         ...
# 2010-01-08  65.09  65.85  64.860  65.46  10633997.0
# 2010-01-07  65.39  66.26  64.940  65.30  11298898.0
# 2010-01-06  65.77  65.81  64.400  65.40  16697355.0
# 2010-01-05  67.00  67.17  64.930  65.80  22064358.0
# 2010-01-04  68.08  68.23  65.640  65.93  19957517.0
#
# [2769 rows x 5 columns]

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(y="Volume")
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(y="Open")
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(y="High")
# Out:
# <Axes: xlabel='Date'>

# %%
df["High"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df[["High", "Close"]].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.available
plt.style.use("fivethirtyeight")

# %%
df.plot(y="Close")
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.use("dark_background")

# %%
df.plot(y="Close")
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.use("ggplot")

# %%
df.plot(y="Volume")
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"]
# Out:
# Date
# 2020-12-31     6.63
# 2020-12-30     6.67
# 2020-12-29     6.77
# 2020-12-28     6.88
# 2020-12-24     7.06
#               ...
# 2010-01-08    65.46
# 2010-01-07    65.30
# 2010-01-06    65.40
# 2010-01-05    65.80
# 2010-01-04    65.93
# Name: Close, Length: 2769, dtype: float64

# %%
def f(x):
    if x <= 10:
        return "Poor"
    elif x <= 50:
        return "Satisfactory" 
    else:
        return "Supreme"

# %%
s = df["Close"].apply(f)

# %%
s.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Close'>

# %%
s = s.value_counts()

# %%
s.plot(kind="bar")
# Out:
# <Axes: xlabel='Close'>

# %%
s.plot.barh()
# Out:
# <Axes: ylabel='Close'>

# %%
avg = df["Close"].mean()
avg
# Out:
# 16.201237811484287

# %%
def g(x):
    if x >= avg:
        return "Above average"
    return "Below average"

# %%
s = df["Close"].apply(g)

# %%
s.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Close'>

# %%
plt.style.use("dark_background")

# %%
s.value_counts().plot(kind="pie", legend=True)
# Out:
# <Axes: ylabel='count'>

# %%
df["Close"].hist()
# Out:
# <Axes: >

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
