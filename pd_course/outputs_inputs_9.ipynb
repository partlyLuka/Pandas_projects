# %% [markdown]
# OUTPUTS AND INPUTS IX

# %%
import pandas as pd

# %%
df = pd.read_csv(r"pandas\pandas\Popular_Baby_Names.csv")

# %%
df
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2019  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 1               2019  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 2               2019  FEMALE  ASIAN AND PACIFIC ISLANDER                Mia
# 3               2019  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 4               2019  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
# ...              ...     ...                         ...                ...
# 57577           2011    MALE          WHITE NON HISPANIC              BRYCE
# 57578           2011    MALE          WHITE NON HISPANIC              DEREK
# 57579           2011    MALE          WHITE NON HISPANIC            STEPHEN
# 57580           2011    MALE          WHITE NON HISPANIC           AUGUSTUS
# 57581           2011    MALE          WHITE NON HISPANIC             CALVIN
#
#        Count  Rank
# 0        131     1
# ...

# %%
df["Child's First Name"].to_dict()
# Out:
# {0: 'Chloe',
#  1: 'Olivia',
#  2: 'Mia',
#  3: 'Sophia',
#  4: 'Emma',
#  5: 'Amelia',
#  6: 'Charlotte',
#  7: 'Emily',
#  8: 'Grace',
#  9: 'Isabella',
#  10: 'Ella',
#  11: 'Ava',
#  12: 'Evelyn',
#  13: 'Hannah',
#  14: 'Bella',
#  15: 'Aria',
#  16: 'Hailey',
#  17: 'Sarah',
#  18: 'Arya',
#  19: 'Claire',
#  20: 'Ellie',
#  21: 'Fatima',
#  22: 'Kayla',
#  23: 'Maryam',
#  24: 'Zoe',
#  25: 'Audrey',
#  26: 'Abigail',
#  27: 'Anna',
#  28: 'Avery',
#  29: 'Alyssa',
#  30: 'Maya',
#  31: 'Tenzin',
#  32: 'Alice',
#  33: 'Celine',
#  34: 'Emilia',
#  35: 'Inaaya',
#  36: 'Jasmine',
#  37: 'Riley',
#  38: 'Sofia',
#  39: 'Zoey',
#  40: 'Alina',
#  41: 'Fiona',
#  42: 'Joanna',
#  43: 'Anaya',
#  44: 'Annie',
#  45: 'Ayesha',
#  46: 'Eva',
#  47: 'Leah',
#  48: 'Luna',
#  49: 'Sophie',
#  50: 'Zainab',
#  51: 'Amaya',
#  52: 'Angela',
#  53: 'Elena',
#  54: 'Mila',
#  55: 'Anabia',
#  56: 'Inaya',
#  57: 'Ariana',
#  58: 'Manha',
#  59: 'Penelope',
#  60: 'Zara',
# ...

# %%
s = df["Child's First Name"]

# %%
l = ["a", "b", "c"]
" , ".join(l)
# Out:
# 'a , b , c'

# %%
", ".join(s.str.title().drop_duplicates().sort_values())
# Out:
# "Aahil, Aaliyah, Aarav, Aaron, Aarya, Aaryan, Aayan, Aayat, Abby, Abdiel, Abdoul, Abdoulaye, Abdul, Abdullah, Abdulloh, Abe, Abel, Abigail, Aboubacar, Abraham, Abrar, Abrielle, Abril, Abubakr, Ace, Ada, Adalynn, Adam, Adan, Addison, Adelaide, Adele, Adelina, Adeline, Adelyn, Adelynn, Aden, Adiel, Adina, Aditya, Adonis, Adrian, Adriana, Adrianna, Adriel, Adyan, Ahad, Aharon, Ahmad, Ahmed, Ahnaf, Ahron, Ahuva, Aicha, Aidan, Aiden, Ailani, Aileen, Aimee, Aisha, Aissata, Aissatou, Aitana, Aiza, Aizah, Akiva, Alahia, Alaia, Alaina, Alan, Alana, Alani, Alanis, Alanna, Alayna, Alba, Albert, Alberto, Aldo, Aleah, Alec, Aleena, Alejandra, Alejandro, Aleksander, Aleksandra, Alessandra, Alessandro, Alessia, Alex, Alexa, Alexander, Alexandra, Alexandria, Alexia, Alexis, Alfred, Alfredo, Ali, Alia, Aliah, Alice, Alicia, Alijah, Alina, Alisa, Alisha, Alison, Alissa, Alisson, Aliya, Aliyah, Aliza, Allan, Allen, Allison, Allyson, Alma, Alondra, Alonso, Alpha, Alston, Alter, Alvin, Alyson, Alyssa, Am
# ...

# %%
df.to_csv("nyc.csv", index=False, columns=["Gender", "Ethnicity", "Child's First Name"], encoding="utf-8")

# %%
import pandas as pd

# %%
pd.read_excel(r"pandas\pandas\Data - Single Worksheet.xlsx")
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
data = pd.read_excel(r"pandas\pandas\Data - Multiple Worksheets.xlsx", sheet_name=["Data 1","Data 2"])

# %%
data["Data 1"]
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
pd.read_excel(r"pandas\pandas\Data - Multiple Worksheets.xlsx", sheet_name=None)
# Out:
# {'Data 1':   First Name Last Name           City Gender
#  0    Brandon     James          Miami      M
#  1       Sean   Hawkins         Denver      M
#  2       Judy       Day    Los Angeles      F
#  3     Ashley      Ruiz  San Francisco      F
#  4  Stephanie     Gomez       Portland      F,
#  'Data 2':   First Name Last Name           City Gender
#  0     Parker     Power        Raleigh      F
#  1    Preston  Prescott   Philadelphia      F
#  2    Ronaldo   Donaldo         Bangor      M
#  3      Megan   Stiller  San Francisco      M
#  4     Bustin    Jieber         Austin      F}

# %%
mask1 = df["Gender"] == "FEMALE"
mask2 = mask1 == False

# %%
girls = df[mask1]
boys = df[mask2]

# %%
genders = df.groupby("Gender")
genders.get_group("FEMALE")
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2019  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 1               2019  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 2               2019  FEMALE  ASIAN AND PACIFIC ISLANDER                Mia
# 3               2019  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 4               2019  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
# ...              ...     ...                         ...                ...
# 51838           2011  FEMALE          WHITE NON HISPANIC             AUTUMN
# 51839           2011  FEMALE          WHITE NON HISPANIC               AYLA
# 51840           2011  FEMALE          WHITE NON HISPANIC             BIANCA
# 51841           2011  FEMALE          WHITE NON HISPANIC             FRIMET
# 51842           2011  FEMALE          WHITE NON HISPANIC           ANGELICA
#
#        Count  Rank
# 0        131     1
# ...

# %%
excel = pd.ExcelWriter("Baby_names.xlsx")
girls.to_excel(excel, sheet_name="Girls", index=False)
boys.to_excel(excel, sheet_name="Boys",  columns=["Year of Birth", "Gender"])
excel.close()

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
