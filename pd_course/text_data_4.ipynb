# %% [markdown]
# TEXT IV

# %%
import pandas as pd

# %%
df = pd.read_csv(r"pandas\pandas\chicago.csv")

# %%
df
# Out:
#                       Name            Position Title        Department  \
# 0          AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2           AARON,  KARINA            POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                       ...               ...
# 32058   ZYGOWICZ,  PETER J            POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E            POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E            POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST              DoIT
# 32062                  NaN                       NaN               NaN
#
#       Employee Annual Salary
# 0                  $90744.00
# 1                  $84450.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1002.1+ KB

# %%
df["Department"] = df["Department"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 784.2+ KB

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isna()
# Out:
#         Name  Position Title  Department  Employee Annual Salary
# 0      False           False       False                   False
# 1      False           False       False                   False
# 2      False           False       False                   False
# 3      False           False       False                   False
# 4      False           False       False                   False
# ...      ...             ...         ...                     ...
# 32058  False           False       False                   False
# 32059  False           False       False                   False
# 32060  False           False       False                   False
# 32061  False           False       False                   False
# 32062   True            True        True                    True
#
# [32063 rows x 4 columns]

# %%
df = df.dropna(how="all")
df
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# ...

# %%
niz = "hello world, i am here"
niz.title()
niz
# Out:
# 'hello world, i am here'

# %%
df["Name"] = df["Name"].str.title()
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_4888\1192047857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"] = df["Name"].str.title()

# %%
df["Position Title"] = df["Position Title"].str.title()
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_4888\104400022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Position Title"] = df["Position Title"].str.title()

# %%
df["Department"].apply(len)
# Out:
# 0        11
# 1         6
# 2         6
# 3        16
# 4        11
#          ..
# 32057    16
# 32058     6
# 32059     6
# 32060     6
# 32061     4
# Name: Department, Length: 32062, dtype: int64

# %%
niz = "hello world"
niz = niz.replace("e", "_LOL_")
niz
# Out:
# 'h_LOL_llo world'

# %%
df.tail(5)
# Out:
#                       Name                  Position Title        Department  \
# 32057  Zygadlo,  Michael J  Frm Of Machinists - Automotive  GENERAL SERVICES
# 32058   Zygowicz,  Peter J                  Police Officer            POLICE
# 32059    Zymantas,  Mark E                  Police Officer            POLICE
# 32060  Zyrkowski,  Carlo E                  Police Officer            POLICE
# 32061  Zyskowski,  Dariusz         Chief Data Base Analyst              DoIT
#
#       Employee Annual Salary
# 32057              $99528.00
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
df["Department"] = df["Department"].str.replace("MGMNT", "MANAGEMENT")
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_4888\2340940369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Department"] = df["Department"].str.replace("MGMNT", "MANAGEMENT")

# %%
df["Employee Annual Salary"].str.replace("$", "").astype(float)
def ali_je_dollar(niz):
    if "$" in niz:
        return True
    return False
df["Employee Annual Salary"].apply(ali_je_dollar).value_counts()
# Out:
# Employee Annual Salary
# True    32062
# Name: count, dtype: int64

# %%
df["Employee Annual Salary"] = df["Employee Annual Salary"].str.replace("$", "").astype(float)
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_4888\4276421931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Employee Annual Salary"] = df["Employee Annual Salary"].str.replace("$", "").astype(float)

# %%
df["Employee Annual Salary"].nlargest(5)
df.iloc[8184]
# Out:
# Name                              Evans,  Ginger S
# Position Title            Commissioner Of Aviation
# Department                                AVIATION
# Employee Annual Salary                    300000.0
# Name: 8184, dtype: object

# %%
def is_water_in(niz):
    if "water" in niz.lower():
        return True
    else:
        return False
mask = df["Position Title"].apply(is_water_in)

# %%
df[mask]
# Out:
#                        Name                                 Position Title  \
# 0           Aaron,  Elvia J                               Water Rate Taker
# 554      Aluise,  Vincent G             Foreman Of Water Pipe Construction
# 671         Ander,  Perry A                               Water Chemist Ii
# 685     Anderson,  Andrew J  District Superintendent Of Water Distribution
# 702       Anderson,  Donald             Foreman Of Water Pipe Construction
# ...                     ...                                            ...
# 29669        Verma,  Anupam           Managing Engineer - Water Management
# 30239   Washington,  Joseph                              Water Chemist Iii
# 30544       West,  Thomas R                   Gen Supt Of Water Management
# 30991    Williams,  Matthew             Foreman Of Water Pipe Construction
# 31405  Woodridge,  Robert L             Foreman Of Water Pipe Construction
#
#              Department  Employee Annual Salary
# ...

# %%
mask1 = df["Position Title"].str.lower().str.contains("water")
df[mask1]
# Out:
#                        Name                                 Position Title  \
# 0           Aaron,  Elvia J                               Water Rate Taker
# 554      Aluise,  Vincent G             Foreman Of Water Pipe Construction
# 671         Ander,  Perry A                               Water Chemist Ii
# 685     Anderson,  Andrew J  District Superintendent Of Water Distribution
# 702       Anderson,  Donald             Foreman Of Water Pipe Construction
# ...                     ...                                            ...
# 29669        Verma,  Anupam           Managing Engineer - Water Management
# 30239   Washington,  Joseph                              Water Chemist Iii
# 30544       West,  Thomas R                   Gen Supt Of Water Management
# 30991    Williams,  Matthew             Foreman Of Water Pipe Construction
# 31405  Woodridge,  Robert L             Foreman Of Water Pipe Construction
#
#              Department  Employee Annual Salary
# ...

# %%
mask = df["Position Title"].str.lower().str.startswith("water")
df[mask]
# Out:
#                          Name           Position Title        Department  \
# 0             Aaron,  Elvia J         Water Rate Taker  WATER MANAGEMENT
# 671           Ander,  Perry A         Water Chemist Ii  WATER MANAGEMENT
# 1054         Ashley,  Karma T         Water Chemist Ii  WATER MANAGEMENT
# 1079        Atkins,  Joanna M         Water Chemist Ii  WATER MANAGEMENT
# 1181       Azeem,  Mohammed A         Water Chemist Ii  WATER MANAGEMENT
# ...                       ...                      ...               ...
# 28574      Threatt,  Denise R  Water Quality Inspector  WATER MANAGEMENT
# 28602       Tignor,  Darryl B         Water Rate Taker  WATER MANAGEMENT
# 28955  Travis Cook,  Leslie R         Water Rate Taker  WATER MANAGEMENT
# 29584        Velazquez,  John         Water Rate Taker  WATER MANAGEMENT
# 30239     Washington,  Joseph        Water Chemist Iii  WATER MANAGEMENT
#
#        Employee Annual Salary
# 0                     90744.0
# ...

# %%
mask = df["Position Title"] == "Water Chemist Ii"
df[mask].sort_values(by="Employee Annual Salary", ascending=False)
# Out:
#                             Name    Position Title        Department  \
# 671              Ander,  Perry A  Water Chemist Ii  WATER MANAGEMENT
# 5506           Cooper Jr,  Eddie  Water Chemist Ii  WATER MANAGEMENT
# 20962            Odibo,  Grace E  Water Chemist Ii  WATER MANAGEMENT
# 20488         Nguyen,  N Anthony  Water Chemist Ii  WATER MANAGEMENT
# 1054            Ashley,  Karma T  Water Chemist Ii  WATER MANAGEMENT
# 14766             Khan,  Aijaz A  Water Chemist Ii  WATER MANAGEMENT
# 2586             Boyce,  Adner L  Water Chemist Ii  WATER MANAGEMENT
# 1079           Atkins,  Joanna M  Water Chemist Ii  WATER MANAGEMENT
# 27635         Stokes,  Carolyn M  Water Chemist Ii  WATER MANAGEMENT
# 21788             Parker,  Terry  Water Chemist Ii  WATER MANAGEMENT
# 23187        Quintanilla,  Edwin  Water Chemist Ii  WATER MANAGEMENT
# 3246        Buchanan,  Anthony L  Water Chemist Ii  WATER MANAGEMENT
# 12781       Howell Jr,  George B  Water Chemist Ii  WATER MANAGEMENT
# ...

# %%
df[df["Position Title"].str.lower().str.endswith("ist")]
# Out:
#                           Name                        Position Title  \
# 184             Afroz,  Nayyar                          Psychiatrist
# 308           Alarcon,  Luis J            Loan Processing Specialist
# 422           Allain,  Carolyn  Senior Telecommunications Specialist
# 472             Allen,  Robert                             Machinist
# 705        Anderson,  Edward M             Sr Procurement Specialist
# ...                        ...                                   ...
# 31667         Yoder,  Teresa G                   Archival Specialist
# 31688  Youngbloom,  Laurence G        Crimes Surveillance Specialist
# 31717       Young,  Kimberly M             Sr Procurement Specialist
# 31837            Zapata,  Hugo             Sr Procurement Specialist
# 31918        Zemke,  Richard P                             Machinist
#
#                   Department  Employee Annual Salary
# 184                   HEALTH                 99840.0
# ...

# %%
niz = "   hello world "
niz.rstrip()
# Out:
# '   hello world'

# %%
df["Name"] = df["Name"].str.strip()
df
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_4888\1011139634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"] = df["Name"].str.strip()
#                       Name                  Position Title        Department  \
# 0          Aaron,  Elvia J                Water Rate Taker  WATER MANAGEMENT
# 1        Aaron,  Jeffery M                  Police Officer            POLICE
# 2           Aaron,  Karina                  Police Officer            POLICE
# 3      Aaron,  Kimberlei R        Chief Contract Expediter  GENERAL SERVICES
# 4      Abad Jr,  Vicente M               Civil Engineer Iv  WATER MANAGEMENT
# ...                    ...                             ...               ...
# ...

# %%
df = pd.read_csv(r"pandas\pandas\chicago.csv", index_col="Name").dropna(how="all")

# %%
df.index = df.index.str.strip().str.title()
df
# Out:
#                                      Position Title        Department  \
# Name
# Aaron,  Elvia J                    WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M                    POLICE OFFICER            POLICE
# Aaron,  Karina                       POLICE OFFICER            POLICE
# Aaron,  Kimberlei R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M               CIVIL ENGINEER IV       WATER MGMNT
# ...                                             ...               ...
# Zygadlo,  Michael J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# Zygowicz,  Peter J                   POLICE OFFICER            POLICE
# Zymantas,  Mark E                    POLICE OFFICER            POLICE
# Zyrkowski,  Carlo E                  POLICE OFFICER            POLICE
# Zyskowski,  Dariusz         CHIEF DATA BASE ANALYST              DoIT
#
#                     Employee Annual Salary
# Name
# Aaron,  Elvia J                  $90744.00
# ...

# %%
df.columns = df.columns.str.upper()
df
# Out:
#                                      POSITION TITLE        DEPARTMENT  \
# Name
# Aaron,  Elvia J                    WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M                    POLICE OFFICER            POLICE
# Aaron,  Karina                       POLICE OFFICER            POLICE
# Aaron,  Kimberlei R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M               CIVIL ENGINEER IV       WATER MGMNT
# ...                                             ...               ...
# Zygadlo,  Michael J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# Zygowicz,  Peter J                   POLICE OFFICER            POLICE
# Zymantas,  Mark E                    POLICE OFFICER            POLICE
# Zyrkowski,  Carlo E                  POLICE OFFICER            POLICE
# Zyskowski,  Dariusz         CHIEF DATA BASE ANALYST              DoIT
#
#                     EMPLOYEE ANNUAL SALARY
# Name
# Aaron,  Elvia J                  $90744.00
# ...

# %%
# Out:
#                                      POSITION TITLE        DEPARTMENT  \
# Name
# Aaron,  Elvia J                    WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M                    POLICE OFFICER            POLICE
# Aaron,  Karina                       POLICE OFFICER            POLICE
# Aaron,  Kimberlei R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M               CIVIL ENGINEER IV       WATER MGMNT
# ...                                             ...               ...
# Zygadlo,  Michael J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# Zygowicz,  Peter J                   POLICE OFFICER            POLICE
# Zymantas,  Mark E                    POLICE OFFICER            POLICE
# Zyrkowski,  Carlo E                  POLICE OFFICER            POLICE
# Zyskowski,  Dariusz         CHIEF DATA BASE ANALYST              DoIT
#
#                     EMPLOYEE ANNUAL SALARY
# Name
# Aaron,  Elvia J                  $90744.00
# ...

# %%
df["Name"].str.split(",").str.get(0).str.title().value_counts()
# Out:
# Name
# Williams     293
# Johnson      244
# Smith        241
# Brown        185
# Jones        183
#             ...
# Horkavy        1
# Horn           1
# Horne Jr       1
# Horner         1
# Zyskowski      1
# Name: count, Length: 13829, dtype: int64

# %%
df["Position Title"].str.split().str.get(0).str.title().value_counts()
# Out:
# Position Title
# Police             10856
# Firefighter-Emt     1509
# Sergeant            1186
# Pool                 918
# Firefighter          810
#                    ...
# Dentist                1
# Assoc                  1
# Telephone              1
# Mayor                  1
# Prepress               1
# Name: count, Length: 320, dtype: int64

# %%
df = df.dropna(how="all")
df
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# ...

# %%
df["Name"].str.split(",").str.get(1).str.split().str.get(0).str.title().value_counts()
# Out:
# Name
# Michael     1153
# John         899
# James        676
# Robert       622
# Joseph       537
#             ...
# Deena          1
# Cherrise       1
# Eartha         1
# Ernika         1
# Mac            1
# Name: count, Length: 5091, dtype: int64

# %%
df["Name"].str.split(",").str.get(1).str.split()
# Out:
# 0            [ELVIA, J]
# 1          [JEFFERY, M]
# 2              [KARINA]
# 3        [KIMBERLEI, R]
# 4          [VICENTE, M]
#               ...
# 32057      [MICHAEL, J]
# 32058        [PETER, J]
# 32059         [MARK, E]
# 32060        [CARLO, E]
# 32061         [DARIUSZ]
# Name: Name, Length: 32062, dtype: object

# %%
df = df.dropna(how="all")
df
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# ...

# %%
df[["First Name", "Last Name"]] = df["Name"].str.split(",", expand=True)
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_2684\1166281854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["First Name", "Last Name"]] = df["Name"].str.split(",", expand=True)
# C:\Users\informatika\AppData\Local\Temp\ipykernel_2684\1166281854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["First Name", "Last Name"]] = df["Name"].str.split(",", expand=True)

# %%
df[["First Title Word", "Remaining"]] = df["Position Title"].str.split(expand=True, n=1)
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_2684\3117956712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["First Title Word", "Remaining"]] = df["Position Title"].str.split(expand=True, n=1)
# C:\Users\informatika\AppData\Local\Temp\ipykernel_2684\3117956712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["First Title Word", "Remaining"]] = df["Position Title"].str.split(expand=True, n=1)

# %%
df
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
# ...

# %%
df.isnull()
# Out:
#         Name  Position Title  Department  Employee Annual Salary  First Name  \
# 0      False           False       False                   False       False
# 1      False           False       False                   False       False
# 2      False           False       False                   False       False
# 3      False           False       False                   False       False
# 4      False           False       False                   False       False
# ...      ...             ...         ...                     ...         ...
# 32057  False           False       False                   False       False
# 32058  False           False       False                   False       False
# 32059  False           False       False                   False       False
# 32060  False           False       False                   False       False
# 32061  False           False       False                   False       False
#
# ...
