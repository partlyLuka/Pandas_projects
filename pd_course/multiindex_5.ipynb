# %% [markdown]
# MULTI INDEX V

# %%
import pandas as pd

# %%
df = pd.read_csv(r"pandas\pandas\bigmac.csv", parse_dates=["Date"])
df
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_15788\601941901.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(r"pandas\pandas\bigmac.csv", parse_dates=["Date"])
#           Date        Country  Price in US Dollars
# 0   2016-01-01      Argentina                 2.39
# 1   2016-01-01      Australia                 3.74
# 2   2016-01-01         Brazil                 3.35
# 3   2016-01-01        Britain                 4.22
# 4   2016-01-01         Canada                 4.14
# ..         ...            ...                  ...
# 647 2010-01-01         Turkey                 3.83
# 648 2010-01-01            UAE                 2.99
# 649 2010-01-01        Ukraine                 1.83
# 650 2010-01-01  United States                 3.58
# 651 2010-01-01        Uruguay                 3.32
#
# [652 rows x 3 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.set_index(keys=["Date", "Country"])
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
df.set_index(keys=["Country", "Date"]).head(59)
# Out:
#                            Price in US Dollars
# Country        Date
# Argentina      2016-01-01                 2.39
# Australia      2016-01-01                 3.74
# Brazil         2016-01-01                 3.35
# Britain        2016-01-01                 4.22
# Canada         2016-01-01                 4.14
# Chile          2016-01-01                 2.94
# China          2016-01-01                 2.68
# Colombia       2016-01-01                 2.43
# Costa Rica     2016-01-01                 4.02
# Czech Republic 2016-01-01                 2.98
# Denmark        2016-01-01                 4.32
# Egypt          2016-01-01                 2.16
# Euro area      2016-01-01                 4.00
# Hong Kong      2016-01-01                 2.48
# Hungary        2016-01-01                 3.08
# India          2016-01-01                 1.90
# Indonesia      2016-01-01                 2.19
# Israel         2016-01-01                 4.29
# ...

# %%
df["Date"].nunique()
df["Country"].nunique()
# Out:
# 58

# %%
df = df.set_index(keys=["Date", "Country"])

# %%
df.sort_index()
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
df.index
# Out:
# MultiIndex([('2016-01-01',      'Argentina'),
#             ('2016-01-01',      'Australia'),
#             ('2016-01-01',         'Brazil'),
#             ('2016-01-01',        'Britain'),
#             ('2016-01-01',         'Canada'),
#             ('2016-01-01',          'Chile'),
#             ('2016-01-01',          'China'),
#             ('2016-01-01',       'Colombia'),
#             ('2016-01-01',     'Costa Rica'),
#             ('2016-01-01', 'Czech Republic'),
#             ...
#             ('2010-01-01',      'Sri Lanka'),
#             ('2010-01-01',         'Sweden'),
#             ('2010-01-01',    'Switzerland'),
#             ('2010-01-01',         'Taiwan'),
#             ('2010-01-01',       'Thailand'),
#             ('2010-01-01',         'Turkey'),
#             ('2010-01-01',            'UAE'),
#             ('2010-01-01',        'Ukraine'),
#             ('2010-01-01',  'United States'),
#             ('2010-01-01',        'Uruguay')],
# ...

# %%
df.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
df.index[0]
# Out:
# (Timestamp('2016-01-01 00:00:00'), 'Argentina')

# %%
df = pd.read_csv(r"pandas\pandas\bigmac.csv", index_col=["Date", "Country"], parse_dates=["Date"])
df.sort_index(inplace=True)
df
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_15788\3689070631.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(r"pandas\pandas\bigmac.csv", index_col=["Date", "Country"], parse_dates=["Date"])
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
df.index.get_level_values(0)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
df.index.set_names(names=["Day", "Location"], inplace=True)

# %%
df.index.set_names(level=0, names="Date")
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
df
# Out:
#                           Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
df = df.set_index(keys=["Date", "Country"])
df
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
df.sort_index(ascending=[False, True])
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Austria                       3.76
#            Belgium                       4.25
#            Brazil                        3.35
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
df.sort_index(level=0)
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
df.sort_index(level=1, ascending=False)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                   2.67
# 2015-07-01 Vietnam                   2.75
# 2015-01-01 Vietnam                   2.81
# 2014-07-01 Vietnam                   2.83
# 2014-01-01 Vietnam                   2.84
# ...                                   ...
# 2012-07-01 Argentina                 4.16
# 2012-01-01 Argentina                 4.64
# 2011-07-01 Argentina                 4.84
# 2010-07-01 Argentina                 3.56
# 2010-01-01 Argentina                 1.84
#
# [652 rows x 1 columns]

# %%
df.loc["2010-01-01", "Argentina"]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
df.loc[("2010-01-01", "Argentina")]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
df.iloc[[3, 5, 77],]
# Out:
#                         Price in US Dollars
# Date       Country
# 2016-01-01 Britain                     4.22
#            Chile                       2.94
# 2015-07-01 New Zealand                 3.91

# %%
bm = df.transpose()

bm.columns
# Out:
# MultiIndex([('2016-01-01',      'Argentina'),
#             ('2016-01-01',      'Australia'),
#             ('2016-01-01',         'Brazil'),
#             ('2016-01-01',        'Britain'),
#             ('2016-01-01',         'Canada'),
#             ('2016-01-01',          'Chile'),
#             ('2016-01-01',          'China'),
#             ('2016-01-01',       'Colombia'),
#             ('2016-01-01',     'Costa Rica'),
#             ('2016-01-01', 'Czech Republic'),
#             ...
#             ('2010-01-01',      'Sri Lanka'),
#             ('2010-01-01',         'Sweden'),
#             ('2010-01-01',    'Switzerland'),
#             ('2010-01-01',         'Taiwan'),
#             ('2010-01-01',       'Thailand'),
#             ('2010-01-01',         'Turkey'),
#             ('2010-01-01',            'UAE'),
#             ('2010-01-01',        'Ukraine'),
#             ('2010-01-01',  'United States'),
#             ('2010-01-01',        'Uruguay')],
# ...

# %%
bm.loc[("Price in US Dollars",), ("2010-01-01","Sri Lanka"):("2010-01-01","Ukraine")]
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 bm.loc[("Price in US Dollars",), ("2010-01-01","Sri Lanka"):("2010-01-01","Ukraine")]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
# ...

# %%
bm.loc[:, ("2010-01-01",)].loc[:, "Sri Lanka":"Ukraine"]
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_15788\200861982.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   bm.loc[:, ("2010-01-01",)].loc[:, "Sri Lanka":"Ukraine"]
# Country              Sri Lanka  Sweden  Switzerland  Taiwan  Thailand  Turkey  \
# Price in US Dollars       1.83    5.51          6.3    2.36      2.11    3.83
#
# Country               UAE  Ukraine
# Price in US Dollars  2.99     1.83

# %%
df = pd.read_csv(r"pandas\pandas\worldstats.csv", index_col=["country", "year"])
df.stack()["Arab World", 2015, "GDP"]
df.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %%
dfs = df.stack()
dfs
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
dfs.unstack().unstack().unstack()
dfs.unstack().unstack().unstack().to_frame().transpose()
dfs.unstack().unstack()
dfs.unstack(0)
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# ...

# %%
df
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12
# ...                      ...           ...
# Zimbabwe   1964    4279561.0  1.217138e+09
#            1963    4140804.0  1.159512e+09
#            1962    4006262.0  1.117602e+09
#            1961    3876638.0  1.096647e+09
#            1960    3752390.0  1.052990e+09
#
# [11211 rows x 2 columns]

# %%
dfs.unstack(0)
dfs.index.set_names(level=2, names="metric", inplace=True)

# %%
dfs = dfs.to_frame()

# %%
dfs.unstack(0).loc[(2015, "GDP"), (0, "Albania")]
# Out:
# 11455595709.1413

# %%
dfs.unstack(1).columns
# Out:
# MultiIndex([(0, 1960),
#             (0, 1961),
#             (0, 1962),
#             (0, 1963),
#             (0, 1964),
#             (0, 1965),
#             (0, 1966),
#             (0, 1967),
#             (0, 1968),
#             (0, 1969),
#             (0, 1970),
#             (0, 1971),
#             (0, 1972),
#             (0, 1973),
#             (0, 1974),
#             (0, 1975),
#             (0, 1976),
#             (0, 1977),
#             (0, 1978),
#             (0, 1979),
#             (0, 1980),
#             (0, 1981),
#             (0, 1982),
#             (0, 1983),
#             (0, 1984),
#             (0, 1985),
#             (0, 1986),
#             (0, 1987),
#             (0, 1988),
#             (0, 1989),
#             (0, 1990),
#             (0, 1991),
#             (0, 1992),
#             (0, 1993),
#             (0, 1994),
#             (0, 1995),
#             (0, 1996),
#             (0, 1997),
#             (0, 1998),
#             (0, 1999),
# ...

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }

# %%
s = df.stack()
s
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
dfs.unstack(0).stack()
# Out:
# year              country
# 1960  Population  Afghanistan           8.994793e+06
#                   Algeria               1.112489e+07
#                   Australia             1.027648e+07
#                   Austria               7.047539e+06
#                   Bahamas, The          1.095260e+05
#                                             ...
# 2015  GDP         Vietnam               1.935994e+11
#                   West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 22422, dtype: float64

# %%
s.unstack().loc[("Afghanistan", 1965), "Population"]
# Out:
# 9935358.0

# %%
s.unstack(0)
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# ...

# %%
s.unstack(level=[0,1])
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                 ...      Zimbabwe                \
# year                2007          2006  ...          1969          1968
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# country                                                             \
# ...

# %%
s.unstack(level=[1,0]).transpose().sort_index().transpose()
# Out:
# year                1960                                            \
# country      Afghanistan       Algeria     Australia       Austria
# Population  8.994793e+06  1.112489e+07  1.027648e+07  7.047539e+06
# GDP         5.377778e+08  2.723638e+09  1.856759e+10  6.592694e+09
#
# year                                                                \
# country     Bahamas, The    Bangladesh       Belgium        Belize
# Population  1.095260e+05  4.820070e+07  9.153489e+06  9.206800e+04
# GDP         1.698023e+08  4.274894e+09  1.165872e+10  2.807248e+07
#
# year                                    ...           2015                \
# country            Benin       Bermuda  ... United Kingdom United States
# Population  2.431620e+06  4.440000e+04  ...   6.513823e+07  3.214188e+08
# GDP         2.261956e+08  8.446665e+07  ...   2.848755e+12  1.794700e+13
#
# year                                                                      \
# ...

# %%
s.unstack(level=[1,0])
s.unstack(1, fill_value=0)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#             GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %%
s.unstack(1).transpose().stack(level=[1, 0])
s.unstack(1).transpose().stack(level=[1,0])
# Out:
# year              country
# 1960  Population  Afghanistan           8.994793e+06
#                   Algeria               1.112489e+07
#                   Australia             1.027648e+07
#                   Austria               7.047539e+06
#                   Bahamas, The          1.095260e+05
#                                             ...
# 2015  GDP         Vietnam               1.935994e+11
#                   West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 22422, dtype: float64

# %%
df.stack().swaplevel(0,2).sort_index(level=0, ascending=False)["Population"].index
# Out:
# MultiIndex([(2015,            'Zimbabwe'),
#             (2015,              'Zambia'),
#             (2015,               'World'),
#             (2015,  'West Bank and Gaza'),
#             (2015,             'Vietnam'),
#             (2015,          'Uzbekistan'),
#             (2015,             'Uruguay'),
#             (2015, 'Upper middle income'),
#             (2015,       'United States'),
#             (2015,      'United Kingdom'),
#             ...
#             (1960,             'Bermuda'),
#             (1960,               'Benin'),
#             (1960,              'Belize'),
#             (1960,             'Belgium'),
#             (1960,          'Bangladesh'),
#             (1960,        'Bahamas, The'),
#             (1960,             'Austria'),
#             (1960,           'Australia'),
#             (1960,             'Algeria'),
#             (1960,         'Afghanistan')],
#            names=['year', 'country'], length=11211)

# %%
df.stack().swaplevel(0,2).sort_index(level=[0,1], ascending=False)[("Population", 2015)]
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_1884\4027471886.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.stack().swaplevel(0,2).sort_index(level=[0,1], ascending=False)[("Population", 2015)]
# country
# Zimbabwe               1.560275e+07
# Zambia                 1.621177e+07
# World                  7.346633e+09
# West Bank and Gaza     4.422143e+06
# Vietnam                9.170380e+07
#                            ...
# Antigua and Barbuda    9.181800e+04
# Angola                 2.502197e+07
# Algeria                3.966652e+07
# Albania                2.889167e+06
# Afghanistan            3.252656e+07
# Length: 215, dtype: float64

# %%
sale = pd.read_csv(r"pandas\pandas\salesmen.csv", parse_dates=["Date"])
sale
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_15788\897790250.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sale = pd.read_csv(r"pandas\pandas\salesmen.csv", parse_dates=["Date"])
#            Date Salesman  Revenue
# 0    2016-01-01      Bob     7172
# 1    2016-01-02      Bob     6362
# 2    2016-01-03      Bob     5982
# 3    2016-01-04      Bob     7917
# 4    2016-01-05      Bob     7837
# ...         ...      ...      ...
# 1825 2016-12-27    Oscar      835
# 1826 2016-12-28    Oscar     3073
# 1827 2016-12-29    Oscar     6424
# 1828 2016-12-30    Oscar     7088
# 1829 2016-12-31    Oscar     8408
#
# [1830 rows x 3 columns]

# %%
sale["Salesman"] = sale["Salesman"].astype("category")
sale
# Out:
#            Date Salesman  Revenue
# 0    2016-01-01      Bob     7172
# 1    2016-01-02      Bob     6362
# 2    2016-01-03      Bob     5982
# 3    2016-01-04      Bob     7917
# 4    2016-01-05      Bob     7837
# ...         ...      ...      ...
# 1825 2016-12-27    Oscar      835
# 1826 2016-12-28    Oscar     3073
# 1827 2016-12-29    Oscar     6424
# 1828 2016-12-30    Oscar     7088
# 1829 2016-12-31    Oscar     8408
#
# [1830 rows x 3 columns]

# %%
sale.set_index(keys=["Salesman", "Date"])
# Out:
#                      Revenue
# Salesman Date
# Bob      2016-01-01     7172
#          2016-01-02     6362
#          2016-01-03     5982
#          2016-01-04     7917
#          2016-01-05     7837
# ...                      ...
# Oscar    2016-12-27      835
#          2016-12-28     3073
#          2016-12-29     6424
#          2016-12-30     7088
#          2016-12-31     8408
#
# [1830 rows x 1 columns]

# %%
sale.set_index(keys=["Date", "Salesman"]).stack().unstack(level=[1,2]).sort_index()
# Out:
# Salesman       Bob  Ronald    Dave     Jeb   Oscar
#            Revenue Revenue Revenue Revenue Revenue
# Date
# 2016-01-01    7172    2639    1864    4430    5250
# 2016-01-02    6362    4951    8278    8026    8661
# 2016-01-03    5982    2703    4226    5188    7075
# 2016-01-04    7917    4258    3868    3144    2524
# 2016-01-05    7837    7771    2287     938    2793
# ...            ...     ...     ...     ...     ...
# 2016-12-27    2045    2981    2843    6666     835
# 2016-12-28     100    6129    8888    1243    3073
# 2016-12-29    4115    7662    9490    3498    6424
# 2016-12-30    2577    2570    3594    8858    7088
# 2016-12-31    3845    2619    6830    9717    8408
#
# [366 rows x 5 columns]

# %%
sale.pivot(index="Date", columns="Salesman", values="Revenue")
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %%
food = pd.read_csv(r"pandas\pandas\foods.csv")
food.pivot_table(values="Spend", index=["Gender", "Item"], aggfunc="max", columns=["City"])
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger        98.96         97.79     85.06
#        Burrito       92.25         96.79     99.21
#        Chalupa       98.43         99.29     98.78
#        Donut         95.63         96.52     91.75
#        Ice Cream     97.83         88.14     97.44
#        Sushi         99.51         99.02     95.43
# Male   Burger        90.32         99.68     97.20
#        Burrito       98.04         93.27     95.07
#        Chalupa       96.44         98.40     99.87
#        Donut         86.70         93.12     99.26
#        Ice Cream     97.65         99.24     99.17
#        Sushi         93.85         97.12     98.48

# %%
pd.pivot_table(food,values="Spend", index=["Gender", "Item"], aggfunc="max", columns=["City"] )
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger        98.96         97.79     85.06
#        Burrito       92.25         96.79     99.21
#        Chalupa       98.43         99.29     98.78
#        Donut         95.63         96.52     91.75
#        Ice Cream     97.83         88.14     97.44
#        Sushi         99.51         99.02     95.43
# Male   Burger        90.32         99.68     97.20
#        Burrito       98.04         93.27     95.07
#        Chalupa       96.44         98.40     99.87
#        Donut         86.70         93.12     99.26
#        Ice Cream     97.65         99.24     99.17
#        Sushi         93.85         97.12     98.48

# %%
food
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# ..         ...     ...           ...       ...        ...    ...
# 995      Donna  Female      New York   Monthly      Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily      Sushi  72.88
# 997       Jean  Female      Stamford    Weekly      Donut   5.85
# 998    Jessica  Female      New York     Daily    Chalupa  43.19
# 999      Brian    Male      New York     Daily    Chalupa  28.36
#
# [1000 rows x 6 columns]

# %%
df = pd.read_csv(r"pandas\pandas\quarters.csv")
df
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(df, id_vars="Salesman", var_name="Quarter", value_name="Revenue")
# Out:
#    Salesman Quarter  Revenue
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...
