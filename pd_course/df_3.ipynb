# %% [markdown]
# DATA FRAME III

# %%
import pandas as pd

# %%
df = pd.read_csv(r"pandas\pandas\jamesbond.csv")
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
df = df.set_index(keys="Film")
df
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
df = df.reset_index()
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
df = df.set_index(keys="Film")

# %%
df = df.reset_index()
df = df.set_index("Year")
df
# Out:
#                                  Film           Actor            Director  \
# Year
# 1962                           Dr. No    Sean Connery       Terence Young
# 1963            From Russia with Love    Sean Connery       Terence Young
# 1964                       Goldfinger    Sean Connery        Guy Hamilton
# 1965                      Thunderball    Sean Connery       Terence Young
# 1967                    Casino Royale     David Niven          Ken Hughes
# 1967              You Only Live Twice    Sean Connery       Lewis Gilbert
# 1969  On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# 1971             Diamonds Are Forever    Sean Connery        Guy Hamilton
# 1973                 Live and Let Die     Roger Moore        Guy Hamilton
# 1974      The Man with the Golden Gun     Roger Moore        Guy Hamilton
# 1977             The Spy Who Loved Me     Roger Moore       Lewis Gilbert
# 1979                        Moonraker     Roger Moore       Lewis Gilbert
# ...

# %%
df = df.reset_index()
df = df.set_index("Film")
df
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
df = df.sort_index()

# %%
df.loc["Goldfinger"]["Budget"]
# Out:
# 18.6

# %%
df.loc["GoldenEye"]
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
df.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
df.loc["Diamonds Are Forever":"From Russia with love"]
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery   Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery  Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore      John Glen       449.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6

# %%
df.loc["GoldenEye":]
# Out:
#                                  Year           Actor            Director  \
# Film
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# ...

# %%
df.loc[:"From Russia with love"]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Casino Royale           145.3                3.3
# Casino Royale            85.0                NaN
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# ...

# %%
df.loc[["Die Another Day", "From Russia with Love"]]
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Die Another Day         154.2               17.9
# From Russia with Love    12.6                1.6

# %%
df.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
df
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
df.iloc[0]
df.iloc[15]
df.iloc[[15, 20]]
df.iloc[4:8]
df.iloc[20:]
# Out:
#                              Year           Actor            Director  \
# Film
# The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me         1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough      1999  Pierce Brosnan       Michael Apted
# Thunderball                  1965    Sean Connery       Terence Young
# Tomorrow Never Dies          1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice          1967    Sean Connery       Lewis Gilbert
#
#                              Box Office  Budget  Bond Actor Salary
# Film
# The Man with the Golden Gun       334.0    27.7                NaN
# The Spy Who Loved Me              533.0    45.1                NaN
# The World Is Not Enough           439.5   158.3               13.5
# Thunderball                       848.1    41.9                4.7
# Tomorrow Never Dies               463.2   133.9               10.0
# ...

# %%
df.iloc[:3]
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
df = df.set_index(keys="Film")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df = df.set_index(keys="Film")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:5859, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5856                 missing.append(col)
#    5858 if missing:
# -> 5859     raise KeyError(f"None of {missing} are in the columns")
#    5861 if inplace:
#    5862     frame = self
#
# KeyError: "None of ['Film'] are in the columns"

# %%
df.sort_index(inplace=True)

# %%
df.iloc[2]
# Out:
# Year                        1967
# Actor                David Niven
# Director              Ken Hughes
# Box Office                 315.0
# Budget                      85.0
# Bond Actor Salary            NaN
# Name: Casino Royale, dtype: object

# %%
df.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
df.iloc[22:]
df.sort_values(by="Year", ascending=False)
# Out:
#                                  Year           Actor            Director  \
# Film
# Spectre                          2015    Daniel Craig          Sam Mendes
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Licence to Kill                  1989  Timothy Dalton           John Glen
# The Living Daylights             1987  Timothy Dalton           John Glen
# A View to a Kill                 1985     Roger Moore           John Glen
# Octopussy                        1983     Roger Moore           John Glen
# ...

# %%
df
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
df.loc["Moonraker", "Year"]
df.loc["Moonraker", "Director"]
df.loc["Moonraker", ["Director", "Box Office"]]
df.loc[["Moonraker", "From Russia with Love"], "Year":"Box Office"]
# Out:
#                        Year         Actor       Director  Box Office
# Film
# Moonraker              1979   Roger Moore  Lewis Gilbert       535.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8

# %%
df.loc["Moonraker":, :"Director"]
# Out:
#                                  Year           Actor            Director
# Film
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# ...

# %%
df.iloc[3:5,5]
# Out:
# Film
# Diamonds Are Forever     5.8
# Die Another Day         17.9
# Name: Bond Actor Salary, dtype: float64

# %%
df.loc["Dr. No", "Actor"] = "Sir Sear Conray"

# %%
df.loc["Dr. No", "Actor"]
df.loc["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]] = df.loc["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]] * 1000000

# %%
df.loc["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]]
# Out:
# Box Office           448800000.0
# Budget                 7000000.0
# Bond Actor Salary       600000.0
# Name: Dr. No, dtype: object

# %%
df = df.set_index(keys="Film")
df
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
df = df.sort_index()

# %%
actor_is_sean = df["Actor"] == "Sean Connery"

# %%
df.loc[actor_is_sean, "Actor"] = "Sir Sear Connery"

# %%
df
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sear Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sear Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sear Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sear Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
df.rename(axis=0, mapper={"GoldenEye" : "Golden Eye", "The World Is Not Enough" : "Best Bond Movie" })
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sear Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sear Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sear Connery       Terence Young
# Golden Eye                       1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sear Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
df.rename(index={"GoldenEye" : "Golden Eye", "The World Is Not Enough" : "Best Bond Movie" })
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sear Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sear Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sear Connery       Terence Young
# Golden Eye                       1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sear Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
df.head(1)
df.rename(axis=1, mapper={"Year": "Release Date"})
# Out:
#                                  Release Date             Actor  \
# Film
# A View to a Kill                         1985       Roger Moore
# Casino Royale                            2006      Daniel Craig
# Casino Royale                            1967       David Niven
# Diamonds Are Forever                     1971  Sir Sear Connery
# Die Another Day                          2002    Pierce Brosnan
# Dr. No                                   1962  Sir Sear Connery
# For Your Eyes Only                       1981       Roger Moore
# From Russia with Love                    1963  Sir Sear Connery
# GoldenEye                                1995    Pierce Brosnan
# Goldfinger                               1964  Sir Sear Connery
# Licence to Kill                          1989    Timothy Dalton
# Live and Let Die                         1973       Roger Moore
# Moonraker                                1979       Roger Moore
# Never Say Never Again                    1983  Sir Sear Connery
# ...

# %%
df.drop(labels="A View to a Kill")
# Out:
#                                  Year             Actor            Director  \
# Film
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sear Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sear Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sear Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sear Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# Live and Let Die                 1973       Roger Moore        Guy Hamilton
# ...

# %%
df.drop(labels=["A View to a Kill", "From Russia with Love"])
df.drop(labels="Casino Royale")
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Diamonds Are Forever             1971  Sir Sear Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sear Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sear Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sear Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# Live and Let Die                 1973       Roger Moore        Guy Hamilton
# Moonraker                        1979       Roger Moore       Lewis Gilbert
# ...

# %%
df.drop("Box Office", axis=1)
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sear Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sear Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sear Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sear Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
actor = df.pop("Actor")

# %%
actor
# Out:
# Film
# A View to a Kill                        Roger Moore
# Casino Royale                          Daniel Craig
# Casino Royale                           David Niven
# Diamonds Are Forever               Sir Sear Connery
# Die Another Day                      Pierce Brosnan
# Dr. No                             Sir Sear Connery
# For Your Eyes Only                      Roger Moore
# From Russia with Love              Sir Sear Connery
# GoldenEye                            Pierce Brosnan
# Goldfinger                         Sir Sear Connery
# Licence to Kill                      Timothy Dalton
# Live and Let Die                        Roger Moore
# Moonraker                               Roger Moore
# Never Say Never Again              Sir Sear Connery
# Octopussy                               Roger Moore
# On Her Majesty's Secret Service      George Lazenby
# Quantum of Solace                      Daniel Craig
# Skyfall                                Daniel Craig
# ...

# %%
del df["Director"]

# %%
df = df.set_index(keys="Film")

# %%
df.sample(frac=0.1)
# Out:
#                   Year         Actor  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No            1962  Sean Connery       448.8     7.0                0.6
# A View to a Kill  1985   Roger Moore       275.2    54.5                9.1
# Casino Royale     1967   David Niven       315.0    85.0                NaN

# %%
df.sample(n=3, axis=1)
# Out:
#                                  Budget  Bond Actor Salary  Box Office
# Film
# Dr. No                              7.0                0.6       448.8
# From Russia with Love              12.6                1.6       543.8
# Goldfinger                         18.6                3.2       820.4
# Thunderball                        41.9                4.7       848.1
# Casino Royale                      85.0                NaN       315.0
# You Only Live Twice                59.9                4.4       514.2
# On Her Majesty's Secret Service    37.3                0.6       291.5
# Diamonds Are Forever               34.7                5.8       442.5
# Live and Let Die                   30.8                NaN       460.3
# The Man with the Golden Gun        27.7                NaN       334.0
# The Spy Who Loved Me               45.1                NaN       533.0
# Moonraker                          91.5                NaN       535.0
# ...

# %%
df.sort_values(by="Box Office", ascending=False)
# Out:
#                                  Year           Actor  Box Office  Budget  \
# Film
# Skyfall                          2012    Daniel Craig       943.5   170.2
# Thunderball                      1965    Sean Connery       848.1    41.9
# Goldfinger                       1964    Sean Connery       820.4    18.6
# Spectre                          2015    Daniel Craig       726.7   206.3
# Casino Royale                    2006    Daniel Craig       581.5   145.3
# From Russia with Love            1963    Sean Connery       543.8    12.6
# Moonraker                        1979     Roger Moore       535.0    91.5
# The Spy Who Loved Me             1977     Roger Moore       533.0    45.1
# GoldenEye                        1995  Pierce Brosnan       518.5    76.9
# You Only Live Twice              1967    Sean Connery       514.2    59.9
# Quantum of Solace                2008    Daniel Craig       514.2   181.4
# Die Another Day                  2002  Pierce Brosnan       465.4   154.2
# ...

# %%
df.nlargest(n=3, columns="Box Office")
df.nsmallest(n=2, columns="Box Office")
# Out:
#                   Year           Actor  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill   1989  Timothy Dalton       250.9    56.7                7.9
# A View to a Kill  1985     Roger Moore       275.2    54.5                9.1

# %%
df.nlargest(n=3, columns="Budget")
# Out:
#                    Year         Actor  Box Office  Budget  Bond Actor Salary
# Film
# Spectre            2015  Daniel Craig       726.7   206.3                NaN
# Quantum of Solace  2008  Daniel Craig       514.2   181.4                8.1
# Skyfall            2012  Daniel Craig       943.5   170.2               14.5

# %%
df.nsmallest(n=6, columns="Bond Actor Salary")
# Out:
#                                  Year           Actor  Box Office  Budget  \
# Film
# Dr. No                           1962    Sean Connery       448.8     7.0
# On Her Majesty's Secret Service  1969  George Lazenby       291.5    37.3
# From Russia with Love            1963    Sean Connery       543.8    12.6
# Goldfinger                       1964    Sean Connery       820.4    18.6
# Casino Royale                    2006    Daniel Craig       581.5   145.3
# You Only Live Twice              1967    Sean Connery       514.2    59.9
#
#                                  Bond Actor Salary
# Film
# Dr. No                                         0.6
# On Her Majesty's Secret Service                0.6
# From Russia with Love                          1.6
# Goldfinger                                     3.2
# Casino Royale                                  3.3
# You Only Live Twice                            4.4

# %%
df["Box Office"].nlargest(6)
df["Year"].nsmallest(2)
# Out:
# Film
# Dr. No                   1962
# From Russia with Love    1963
# Name: Year, dtype: int64

# %%
df = df.sort_index()
mask = df["Actor"] == "Sean Connery"

# %%
df.where(mask)
# Out:
#                                    Year         Actor  Box Office  Budget  \
# Film
# A View to a Kill                    NaN           NaN         NaN     NaN
# Casino Royale                       NaN           NaN         NaN     NaN
# Casino Royale                       NaN           NaN         NaN     NaN
# Diamonds Are Forever             1971.0  Sean Connery       442.5    34.7
# Die Another Day                     NaN           NaN         NaN     NaN
# Dr. No                           1962.0  Sean Connery       448.8     7.0
# For Your Eyes Only                  NaN           NaN         NaN     NaN
# From Russia with Love            1963.0  Sean Connery       543.8    12.6
# GoldenEye                           NaN           NaN         NaN     NaN
# Goldfinger                       1964.0  Sean Connery       820.4    18.6
# Licence to Kill                     NaN           NaN         NaN     NaN
# Live and Let Die                    NaN           NaN         NaN     NaN
# ...

# %%
df = df.set_index(keys="Film")

# %%
df
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
df.columns = [x.replace(" ", "_") for x in df.columns]

# %%
df.query('Director == "Terence Young"')
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
df.query("Box_Office > 500" )
# Out:
#                        Year           Actor         Director  Box_Office  \
# Film
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Thunderball            1965    Sean Connery    Terence Young       848.1
# You Only Live Twice    1967    Sean Connery    Lewis Gilbert       514.2
# The Spy Who Loved Me   1977     Roger Moore    Lewis Gilbert       533.0
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Quantum of Solace      2008    Daniel Craig     Marc Forster       514.2
# Skyfall                2012    Daniel Craig       Sam Mendes       943.5
# Spectre                2015    Daniel Craig       Sam Mendes       726.7
#
#                        Budget  Bond_Actor_Salary
# Film
# ...

# %%
df.query("Actor == 'Roger Moore' and Director == 'John Glen'")
# Out:
#                     Year        Actor   Director  Box_Office  Budget  \
# Film
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
#
#                     Bond_Actor_Salary
# Film
# For Your Eyes Only                NaN
# Octopussy                         7.8
# A View to a Kill                  9.1

# %%
mask = df["Box Office"] > 800
df.where(mask)
# Out:
#                                    Year         Actor  Box Office  Budget  \
# Film
# A View to a Kill                    NaN           NaN         NaN     NaN
# Casino Royale                       NaN           NaN         NaN     NaN
# Casino Royale                       NaN           NaN         NaN     NaN
# Diamonds Are Forever                NaN           NaN         NaN     NaN
# Die Another Day                     NaN           NaN         NaN     NaN
# Dr. No                              NaN           NaN         NaN     NaN
# For Your Eyes Only                  NaN           NaN         NaN     NaN
# From Russia with Love               NaN           NaN         NaN     NaN
# GoldenEye                           NaN           NaN         NaN     NaN
# Goldfinger                       1964.0  Sean Connery       820.4    18.6
# Licence to Kill                     NaN           NaN         NaN     NaN
# Live and Let Die                    NaN           NaN         NaN     NaN
# ...

# %%
col = []
for x in df.columns:
    col.append(x.replace(" ", "_"))
df.columns = col

# %%
df.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery       442.5    34.7
# Dr. No                 1962  Sean Connery       448.8     7.0
# From Russia with Love  1963  Sean Connery       543.8    12.6
# Goldfinger             1964  Sean Connery       820.4    18.6
# Never Say Never Again  1983  Sean Connery       380.0    86.0
# Thunderball            1965  Sean Connery       848.1    41.9
# You Only Live Twice    1967  Sean Connery       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
df.query('Director == "Terence Young"')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\computation\scope.py:233, in Scope.resolve(self, key, is_local)
#     232 if self.has_resolvers:
# --> 233     return self.resolvers[key]
#     235 # if we're here that means that we have no locals and we also have
#     236 # no resolvers
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\collections\__init__.py:986, in ChainMap.__getitem__(self, key)
#     985         pass
# --> 986 return self.__missing__(key)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\collections\__init__.py:978, in ChainMap.__missing__(self, key)
#     977 def __missing__(self, key):
# ...

# %%
df
# Out:
#                                  Year           Actor  Box_Office  Budget  \
# Film
# A View to a Kill                 1985     Roger Moore       275.2    54.5
# Casino Royale                    2006    Daniel Craig       581.5   145.3
# Casino Royale                    1967     David Niven       315.0    85.0
# Diamonds Are Forever             1971    Sean Connery       442.5    34.7
# Die Another Day                  2002  Pierce Brosnan       465.4   154.2
# Dr. No                           1962    Sean Connery       448.8     7.0
# For Your Eyes Only               1981     Roger Moore       449.4    60.2
# From Russia with Love            1963    Sean Connery       543.8    12.6
# GoldenEye                        1995  Pierce Brosnan       518.5    76.9
# Goldfinger                       1964    Sean Connery       820.4    18.6
# Licence to Kill                  1989  Timothy Dalton       250.9    56.7
# Live and Let Die                 1973     Roger Moore       460.3    30.8
# ...

# %%
df.query("Actor in ['Sean Connery', 'Timothy Dalton']")
# Out:
#                        Year           Actor        Director  Box_Office  \
# Film
# Dr. No                 1962    Sean Connery   Terence Young       448.8
# From Russia with Love  1963    Sean Connery   Terence Young       543.8
# Goldfinger             1964    Sean Connery    Guy Hamilton       820.4
# Thunderball            1965    Sean Connery   Terence Young       848.1
# You Only Live Twice    1967    Sean Connery   Lewis Gilbert       514.2
# Diamonds Are Forever   1971    Sean Connery    Guy Hamilton       442.5
# Never Say Never Again  1983    Sean Connery  Irvin Kershner       380.0
# The Living Daylights   1987  Timothy Dalton       John Glen       313.5
# Licence to Kill        1989  Timothy Dalton       John Glen       250.9
#
#                        Budget  Bond_Actor_Salary
# Film
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# ...

# %%
df["Director"].value_counts()["John Glen"]
# Out:
# 5

# %%
df = df.sort_index()
df
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
def f(x):
    return str(x) + " millions"
df["Budget"].apply(f)
# Out:
# Film
# A View to a Kill                    54.5 millions
# Casino Royale                      145.3 millions
# Casino Royale                       85.0 millions
# Diamonds Are Forever                34.7 millions
# Die Another Day                    154.2 millions
# Dr. No                               7.0 millions
# For Your Eyes Only                  60.2 millions
# From Russia with Love               12.6 millions
# GoldenEye                           76.9 millions
# Goldfinger                          18.6 millions
# Licence to Kill                     56.7 millions
# Live and Let Die                    30.8 millions
# Moonraker                           91.5 millions
# Never Say Never Again               86.0 millions
# Octopussy                           53.9 millions
# On Her Majesty's Secret Service     37.3 millions
# Quantum of Solace                  181.4 millions
# Skyfall                            170.2 millions
# Spectre                            206.3 millions
# ...

# %%
col = ["Box Office", "Budget", "Bond Actor Salary"]
for x in col:
    df[x] = df[x].apply(f)
df
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
def good_movie(row):
    actor = row[1]
    budget = row[4]
    if actor == "Pierce Brosnan":
        return "The best"
    elif actor == "Roger Moore" and budget > 40:
        return "Enjoyable"
    return "idk lol"

# %%
df.apply(good_movie, axis=1)
# Out:
# Film
# A View to a Kill                   Enjoyable
# Casino Royale                        idk lol
# Casino Royale                        idk lol
# Diamonds Are Forever                 idk lol
# Die Another Day                     The best
# Dr. No                               idk lol
# For Your Eyes Only                 Enjoyable
# From Russia with Love                idk lol
# GoldenEye                           The best
# Goldfinger                           idk lol
# Licence to Kill                      idk lol
# Live and Let Die                     idk lol
# Moonraker                          Enjoyable
# Never Say Never Again                idk lol
# Octopussy                          Enjoyable
# On Her Majesty's Secret Service      idk lol
# Quantum of Solace                    idk lol
# Skyfall                              idk lol
# Spectre                              idk lol
# The Living Daylights                 idk lol
# The Man with the Golden Gun          idk lol
# ...

# %%
def hala(x):
    if x[0] in range(1900, 2300):
        return "Jej"
    return "LOL"
df.apply(hala)
# Out:
# Year                 Jej
# Actor                LOL
# Director             LOL
# Box Office           LOL
# Budget               LOL
# Bond Actor Salary    LOL
# dtype: object

# %%
s = df["Director"]

# %%
.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 s.head(3)
#
# NameError: name 's' is not defined

# %%
s[0] = "LOL"
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_5956\2950587790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s[0] = "LOL"

# %%
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore                 LOL
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
df = df.set_index("Film").sort_index()
s = df["Director"].

# %%
s[0] = "LOL"
# Out:
# C:\Users\informatika\AppData\Local\Temp\ipykernel_5956\2950587790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s[0] = "LOL"

# %%
df = df.set_index("Film").sort_index()
s = df["Director"].copy()
s
# Out:
# Film
# A View to a Kill                            John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...

# %%
s[0] = "LOL"
df
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...
